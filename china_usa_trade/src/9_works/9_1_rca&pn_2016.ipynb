# %%
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.graph_objects as go
import networkx as nx
import matplotlib.pyplot as plt
from warnings import filterwarnings
filterwarnings('ignore')

# %%
def get_data(
        csvs_root='../../csvs/',
        data_root='../../../../data/trade/BACI/'):
    # RCA BASE TABLE
    rca_n = pd.read_csv(
        csvs_root + 'RCA_n.csv',
        dtype={'product': object, 'flow':int})

    # COMMODITY CODE
    commodity_code = pd.read_csv(
        csvs_root + 'commodity_code.csv',
        encoding='latin-1',
        dtype={'Code': object, 'isLeaf':int, 'Level':int})
    # BACI uses SITC rev 3(S3)
    commodity_code = \
        commodity_code[commodity_code['Classification']=='S3']
    # drop last column
    commodity_code = commodity_code.iloc[:, :-1]

    # COUNTRY NAMES
    country_df = pd.read_csv(data_root + 'countries.csv')
    countries = country_df.Name.values
    countries = np.append(countries, ["United States of America", "China, Hong Kong SAR", "China, Taiwan Province of", "Türkiye", "Iran (Islamic Republic of)", "Czechia", "Switzerland, Liechtenstein", "China, Macao SAR", "Korea, Dem. People's Rep. of", "Venezuela (Bolivarian Rep. of)", "Côte d'Ivoire", "Congo, Dem. Rep. of the", "Lao People's Dem. Rep.", "Bolivia (Plurinational State of)", "North Macedonia", "Curaçao", "State of Palestine", "Cabo Verde", "Eswatini", "British Virgin Islands", "Micronesia (Federated States of)", "Wallis and Futuna Islands", "Holy See",])
    return rca_n, commodity_code, countries

# %% [markdown]
# # 2016 data

# %%
# load data 
csvs_root = '../../csvs/'
data_root = '../../../../data/trade/BACI/'
rca_n, commodity_code, countries = get_data(csvs_root, data_root)

# merge
commodity_code.rename(columns={'Code': 'product'}, inplace=True)
rca_n = rca_n.merge(commodity_code, on='product', how='left')

# %% [markdown]
# # exports only

# %%
# only exports 
rca_n = rca_n[rca_n.flow==2].copy()

# only countries
rca_n_countries = rca_n[rca_n.economy_label.isin(countries)].copy()

# drop columns that aren't included in commodity codes
rca_n_countries.dropna(subset=['Classification'], inplace=True)

# %% [markdown]
# ### there seems to be data missing from level1 to 2&3
# - however, TOTAL and the sum of sum_kusd at each level is the same
# - so for now we will just work on level3

# %%
rca_n_countries.groupby(['Level'])['sum_kusd'].sum().reset_index()

level3_filter = rca_n_countries.Level==3
rca_n_countries = rca_n_countries[level3_filter].copy()

# %% [markdown]
# ## calc RCA
# for the following, apply below steps
# - national ratio
# - international ratio
#
# **steps:**
# 1. aggregate
# 2. rename
# 3. merge
# 4. calc ratio

# %%
# product/sum(product) for each country

sum_per_n = rca_n_countries.groupby(['economy_label'])\
    .agg({'sum_kusd': 'sum'})\
        .reset_index()[['economy_label', 'sum_kusd']]
sum_per_n = sum_per_n.rename({'sum_kusd': 'sum_per_n'}, axis=1)[['economy_label', 'sum_per_n']]

rca_n_countries = pd.merge(rca_n_countries, sum_per_n, on='economy_label', how='left')
rca_n_countries['n_ratio'] = rca_n_countries.apply(lambda x: x['sum_kusd']/x['sum_per_n'], axis=1)


# product/sum(product) across countries

sum_per_p = rca_n_countries.groupby(['product'])\
    .agg({'sum_kusd':'sum'})\
        .reset_index()[['product', 'sum_kusd']]
sum_per_p = sum_per_p.rename({'sum_kusd': 'sum_per_p'}, axis=1)[['product', 'sum_per_p']] # renaming for merging

rca_n_countries = pd.merge(rca_n_countries, sum_per_p, on='product', how='left')

# total of exports
sum_p = rca_n_countries['sum_kusd'].sum()
rca_n_countries['p_ratio'] = rca_n_countries.apply(lambda x: x['sum_per_p']/sum_p, axis=1)

rca_n_countries.sort_values(by=['economy_label','product'], inplace=True)
rca_n_countries.reset_index(drop=True, inplace=True)
rca_n_countries.to_csv('tmp.csv', index=False)

# %% [markdown]
# ### calculate difference between calculated sum of products vs. actual sum of products for china

# %%
economy_name = 'United States of America'
economy_name = 'China'
rca_n_countries_economy_filter = (rca_n_countries.economy_label==economy_name).values
rca_n_economy_filter = (rca_n.economy_label==economy_name).values
calculated_sum_per_n = rca_n_countries[rca_n_countries_economy_filter]['sum_per_n'].unique()
assert len(calculated_sum_per_n) == 1
actual_sum_per_n = rca_n[(rca_n['Level']==0).values & rca_n_economy_filter]['sum_kusd'].values[0]
difference = calculated_sum_per_n[0] - actual_sum_per_n
print(economy_name)
print("(calculated - actual)/actual: ", round(difference/actual_sum_per_n, 3)*100
, "%;\n", " "*29,round(difference/1e6), "million dollars")
# Out:
# China
# (calculated - actual)/actual:  -0.2 %;
#                                -102 million dollars

# %%
china_filter = (rca_n_countries['economy_label'] == 'China').values
usa_filter = (rca_n_countries['economy_label'] == 'United States of America').values
ukraine_filter = (rca_n_countries['economy_label'] == 'Ukraine').values
russia_filter = (rca_n_countries['economy_label'] == 'Russian Federation').values
rca_filter = (rca_n_countries['n_ratio'] > rca_n_countries['p_ratio']).values

china_rca = rca_n_countries[china_filter & rca_filter]
usa_rca = rca_n_countries[usa_filter & rca_filter]

china_rca_top5 = china_rca.sort_values(by=['n_ratio'], ascending=False).head(5)
usa_rca_top5 = usa_rca.sort_values(by=['n_ratio'], ascending=False).head(5)

china_rca_top5_names = china_rca_top5['product'].values
usa_rca_top5_names = usa_rca_top5['product'].values

# get products to make product network from 
top5_union = np.concatenate((china_rca_top5_names, usa_rca_top5_names))
top5_union = np.unique(top5_union)

# %%
fig = go.Figure()
fig.add_trace(
    go.Bar(
        x=china_rca_top5['product'],
        y=china_rca_top5['sum_kusd'],
        name='China'))
fig.add_trace(
    go.Bar(
        x=usa_rca_top5['product'],
        y=usa_rca_top5['sum_kusd'],
        name='USA'))
fig.show()

# %% [markdown]
# ## compute centrality

# %% [markdown]
# ### load data

# %%
csvs_root='../../csvs/'
for_pn = pd.read_csv(
    csvs_root + 'for_product_network.csv',
    dtype={'product': object, 'flow':int})

# only working with countries
partner_country_filter = (for_pn['partner_label'].isin(countries)).values
economy_country_filter = (for_pn['economy_label'].isin(countries)).values
for_pn_countries = for_pn[\
    partner_country_filter & economy_country_filter].copy()

# merge with commodity code
for_pn_countries = \
    for_pn_countries.merge(commodity_code, on='product', how='left')

# %% [markdown]
# ## work on china's biggest export
# (telecommunication equipment, n.e.s; & parts...)

# %%
product_df = for_pn_countries[for_pn_countries['product']=='764']\
    [[
        'economy_label',
        'partner_label',
        'flow',
        'kusd'
    ]]
export_product_df = product_df[product_df['flow']==2]

# %% [markdown]
# ### truncate data
# - most of the transactions are not that big

# %%
px.histogram(product_df.kusd, log_y=True).show()

# %%
# kusd_arr = product_df.kusd.values
# kusd_sum = kusd_arr.sum()
# percentile = 5
# # sort kusd_arr in ascending order
# kusd_arr.sort()
# tmp_sum = 0
# for val in kusd_arr:
#     tmp_sum += val
#     if tmp_sum/kusd_sum > percentile/100:
#         kusd_trunc = val
#         break
# kusd_trunc

product_df = product_df[product_df['kusd'] > 10000].copy()

# %%
export_product_df.groupby(['economy_label'])\
    .agg({'kusd': 'sum', 'partner_label':'count'} )\
        .reset_index()\
            .sort_values(by=['kusd'], ascending=False)\
                .head(5)
# Out:
#                 economy_label          kusd  partner_label
# 42                      China  2.323624e+08            207
# 43       China, Hong Kong SAR  9.139167e+07            191
# 207  United States of America  4.363218e+07            211
# 212                  Viet Nam  3.861327e+07            119
# 107        Korea, Republic of  3.217263e+07            173

# %% [markdown]
# ### create network

# %%
G = nx.DiGraph()
export_nodes = list(product_df.economy_label.unique())
import_nodes = list(product_df.partner_label.unique())
G.add_nodes_from(export_nodes, node_type='export')
G.add_nodes_from(import_nodes, node_type='import')

for index, row in product_df.iterrows():
    exporter = row['economy_label']
    importer = row['partner_label']
    kusd = row['kusd']
    G.add_edge(exporter, importer, weight=kusd)

# %% [markdown]
# ### degree centrality of china

# %%
# compute degree centrality of China
dc = nx.out_degree_centrality(G)
df_dc = \
    pd.DataFrame.from_dict(dc, orient='index', columns=['out_degree_centrality'])
df_dc = df_dc.reset_index().rename({'index': 'economy_label'}, axis=1)
df_dc = df_dc.sort_values(by=['out_degree_centrality'], ascending=False)
china_dc = \
    df_dc[df_dc['economy_label']=='China']['out_degree_centrality'].values[0]
print("china's out_degree centrality:", china_dc)

ec = nx.eigenvector_centrality(G)
df_ec = \
    pd.DataFrame.from_dict(ec, orient='index', columns=['eigenvector_centrality'])
df_ec = df_ec.reset_index().rename({'index': 'economy_label'}, axis=1)
df_ec = df_ec.sort_values(by=['eigenvector_centrality'], ascending=False)
china_ec = \
    df_ec[df_ec['economy_label']=='China']['eigenvector_centrality'].values[0]
print("china's eigenvector centrality:", china_ec)
# Out:
# china's out_degree centrality: 0.7403846153846154
# china's eigenvector centrality: 0.35349946906428237

# %%
df_dc.head(5)
# Out:
#                economy_label  out_degree_centrality
# 17                     China               0.740385
# 33      China, Hong Kong SAR               0.596154
# 94  United States of America               0.490385
# 80                  Viet Nam               0.394231
# 30                   Germany               0.355769

# %%
df_ec.head(5)
# Out:
#                economy_label  eigenvector_centrality
# 17                     China                0.353499
# 80                  Viet Nam                0.268654
# 94  United States of America                0.259562
# 62               Netherlands                0.234891
# 30                   Germany                0.224901

# %%
# create edges
pos = nx.spring_layout(G, k=1)
# pos = nx.kamada_kawai_layout(G)
# pos = nx.nx_agraph.graphviz_layout(G, prog='dot')

edge_x = []
edge_y = []
for edge in G.edges():
    x0 = pos[edge[0]][0]
    y0 = pos[edge[0]][1]
    x1 = pos[edge[1]][0]
    y1 = pos[edge[1]][1]

    edge_x.append(x0)
    edge_x.append(x1)
    edge_x.append(None)
    edge_y.append(y0)
    edge_y.append(y1)
    edge_y.append(None)

edge_trace = go.Scatter(
    x=edge_x, y=edge_y,
    line=dict(width=0.5, color='#888'),
    hoverinfo='none',
    mode='lines')

# create nodes
node_x = []
node_y = []
for node in G.nodes():
    x, y = pos[node][0], pos[node][1]
    node_x.append(x)
    node_y.append(y)

node_trace = go.Scatter(
    x=node_x, y=node_y,
    mode='markers',
    hoverinfo='text',
    marker=dict(
        showscale=True,
        colorscale='YlGnBu',
        reversescale=True,
        color=[],
        size=10,
        colorbar=dict(
            thickness=15,
            title='Node Connections',
            xanchor='left',
            titleside='right'
        ),
        line_width=2))
    
# color nodes
node_adjacencies = []
node_text = []
for node, adjacencies in enumerate(G.adjacency()):
    node_adjacencies.append(len(adjacencies[1]))
    # node_text.append('# of connections: '+str(len(adjacencies[1])))
    node_text.append(adjacencies[0])

node_trace.marker.color = node_adjacencies
node_trace.text = node_text

# create network graph
fig = go.Figure(data=[edge_trace, node_trace],
                layout=go.Layout(
                    title='Network Graph of Product 764',
                    titlefont_size=16,
                    showlegend=False,
                    hovermode='closest',
                    margin=dict(b=20,l=5,r=5,t=40),
                    annotations=[dict(
                        text="",
                        showarrow=False,
                        xref="paper", yref="paper",
                        x=0.005, y=-0.002 ) ],
                    xaxis=dict(showgrid=False, zeroline=False, showticklabels=False), 
                    yaxis=dict(showgrid=False, zeroline=False, showticklabels=False))
                    )
fig.show()

# %%
for node, adjacency in enumerate(G.adjacency()):
# Out:
# [('Afghanistan',
#   {'Antigua and Barbuda': {'weight': 0.1400000006},
#    'Australia': {'weight': 6051.5249023},
#    'Austria': {'weight': 0.0219999999},
#    'Bangladesh': {'weight': 0.1379999965},
#    'Belgium': {'weight': 166.95199585},
#    'Bosnia and Herzegovina': {'weight': 0.6169999838},
#    'Brunei Darussalam': {'weight': 0.061999999},
#    'Bulgaria': {'weight': 2.1860001087},
#    'Canada': {'weight': 8.2089996338},
#    'Sri Lanka': {'weight': 19.523000717},
#    'Chile': {'weight': 2.0280001163},
#    'China': {'weight': 520.20098877},
#    'China, Taiwan Province of': {'weight': 58.958999634},
#    'Croatia': {'weight': 0.0489999987},
#    'Czechia': {'weight': 7.2249999046},
#    'Denmark': {'weight': 100.25099945},
#    'Finland': {'weight': 0.6679999828},
#    'France': {'weight': 43.803001404},
#    'Germany': {'weight': 12.770999908},
#    'Greece': {'weight': 3.7990000248},
#    'China, Hong Kong SAR': {'weight': 20.979000092},
#    'Hungary': {'weight': 30.646999359},
#    'India': {'weight': 7.7199997902},
#    'Indonesia': {'weight': 350.44799805},
#    'Iran (Islamic Republic of)': {'weight': 297.18200684},
#    'Ireland': {'weight': 0.6079999804},
#    'Israel': {'weight': 48.438999176},
#    'Italy': {'weight': 4.0260000229},
#    'Japan': {'weight': 254.8999939},
#    'Korea, Republic of': {'weight': 0.3619999886},
#    'Lebanon': {'weight': 302.45001221},
#    'Latvia': {'weight': 36.373001099},
#    'Lithuania': {'weight': 23.629999161},
#    'Malaysia': {'weight': 51.269001007},
#    'Malta': {'weight': 0.0719999969},
#    'Moldova, Republic of': {'weight': 0.3849999905},
#    'Mozambique': {'weight': 1.4589999914},
#    'Netherlands': {'weight': 136.47200012},
#    'New Zealand': {'weight': 0.2339999974},
#    'Norway': {'weight': 192.89199829},
#    'Pakistan': {'weight': 19.952999115},
#    'Philippines': {'weight': 127.56999969},
#    'Poland': {'weight': 0.1599999964},
#    'Portugal': {'weight': 10.798999786},
#    'Russian Federation': {'weight': 3.9730000496},
#    'Senegal': {'weight': 4.3979997635},
#    'Singapore': {'weight': 11.197999954},
#    'Viet Nam': {'weight': 624.00897217},
#    'South Africa': {'weight': 0.2169999927},
#    'Spain': {'weight': 2.1740000248},
#    'Sweden': {'weight': 1.3059999943},
#    'Switzerland, Liechtenstein': {'weight': 0.1140000001},
#    'Tajikistan': {'weight': 26.868999481},
#    'Thailand': {'weight': 0.0410000011},
#    'Togo': {'weight': 0.4379999936},
#    'United Arab Emirates': {'weight': 167864.67188},
#    'Türkiye': {'weight': 163.38499451},
#    'United States of America': {'weight': 539.07897949},
#    'United Kingdom': {'weight': 7.2709999084}}),
#  ('Albania',
#   {'Australia': {'weight': 0.4709999859},
#    'Austria': {'weight': 4.8439998627},
#    'Belgium': {'weight': 5.6810002327},
#    'Bosnia and Herzegovina': {'weight': 5.1770000458},
#    'Bulgaria': {'weight': 0.6949999928},
#    'Canada': {'weight': 340.66101074},
#    'China': {'weight': 0.0500000007},
#    'China, Taiwan Province of': {'weight': 335.38699341},
#    'Croatia': {'weight': 17.193000793},
#    'Czechia': {'weight': 1.3710000515},
#    'Denmark': {'weight': 2.0880000591},
#    'Finland': {'weight': 0.3899999857},
#    'France': {'weight': 95.36000061},
#    'Germany': {'weight': 22.999000549},
#    'Greece': {'weight': 3.3499999046},
#    'China, Hong Kong SAR': {'weight': 137.26100159},
#    'Hungary': {'weight': 22.933000565},
#    'India': {'weight': 9.1669998169},
#    'Indonesia': {'weight': 32.933998108},
#    'Ireland': {'weight': 0.2520000041},
#    'Israel': {'weight': 115.88400269},
#    'Italy': {'weight': 165.71800232},
#    'Japan': {'weight': 118.95200348},
#    'Korea, Republic of': {'weight': 893.88800049},
#    'Kuwait': {'weight': 9.8219995499},
#    'Lebanon': {'weight': 24.788999557},
#    'Latvia': {'weight': 256.91299438},
#    'Lithuania': {'weight': 237.29100037},
#    'Malaysia': {'weight': 54.664001465},
#    'Mexico': {'weight': 279.22198486},
#    'Morocco': {'weight': 0.0390000008},
#    'Netherlands': {'weight': 1653.2779541},
#    'Norway': {'weight': 0.2529999912},
#    'Poland': {'weight': 5.3480000496},
#    'Romania': {'weight': 25.87100029},
#    'Senegal': {'weight': 5.4060001373},
#    'Serbia': {'weight': 244.50700378},
#    'Singapore': {'weight': 2.763999939},
#    'Slovakia': {'weight': 18.840000153},
#    'Viet Nam': {'weight': 6222.4702148},
#    'Slovenia': {'weight': 2.3489999771},
#    'Sweden': {'weight': 0.7720000148},
#    'Switzerland, Liechtenstein': {'weight': 1.7649999857},
#    'Thailand': {'weight': 0.0780000016},
#    'United Arab Emirates': {'weight': 0.0099999998},
#    'Türkiye': {'weight': 0.1700000018},
#    'North Macedonia': {'weight': 17.983999252},
#    'United States of America': {'weight': 35.970001221},
#    'United Kingdom': {'weight': 68.299003601}}),
#  ('Algeria',
#   {'Angola': {'weight': 83.490997314},
#    'Australia': {'weight': 203.33000183},
#    'Austria': {'weight': 332.19900513},
#    'Belgium': {'weight': 0.0109999999},
#    'Brazil': {'weight': 29.833999634},
#    'Bulgaria': {'weight': 731.3460083},
#    'Myanmar': {'weight': 0.0520000011},
#    'Canada': {'weight': 647.50402832},
#    'Cabo Verde': {'weight': 0.9520000219},
#    'China': {'weight': 17.6060009},
#    'China, Taiwan Province of': {'weight': 5820.637207},
#    'Costa Rica': {'weight': 346.63598633},
#    'Cyprus': {'weight': 0.8050000072},
#    'Czechia': {'weight': 4970.5952148},
#    'Denmark': {'weight': 189.25799561},
#    'El Salvador': {'weight': 144.66200256},
#    'Estonia': {'weight': 8749.3925781},
#    'Finland': {'weight': 3754.4760742},
#    'France': {'weight': 7.3309998512},
#    'Germany': {'weight': 65.424003601},
#    'Greece': {'weight': 0.0500000007},
#    'China, Hong Kong SAR': {'weight': 817.92199707},
#    'Hungary': {'weight': 7293.027832},
#    'Iceland': {'weight': 0.9359999895},
#    'India': {'weight': 959.13500977},
#    'Indonesia': {'weight': 266.95999146},
#    'Ireland': {'weight': 1287.8800049},
#    'Italy': {'weight': 10040.078125},
#    'Japan': {'weight': 0.0939999968},
#    'Jordan': {'weight': 0.2509999871},
#    'Kenya': {'weight': 0.451000005},
#    "Korea, Dem. People's Rep. of": {'weight': 3.4549999237},
#    'Korea, Republic of': {'weight': 3.9909999371},
#    'Lebanon': {'weight': 10.706000328},
#    'Latvia': {'weight': 110.22299957},
#    'Lithuania': {'weight': 65.786003113},
#    'Malaysia': {'weight': 9138.6416016},
#    'Maldives': {'weight': 34.516998291},
#    'Malta': {'weight': 21.790000916},
#    'Mauritania': {'weight': 9.1770000458},
#    'Mexico': {'weight': 1875.0710449},
#    'Morocco': {'weight': 4.236000061},
#    'Netherlands': {'weight': 7.6069998741},
#    'New Zealand': {'weight': 19.153999329},
#    'Norway': {'weight': 3732.5959473},
#    'Pakistan': {'weight': 1.6890000105},
#    'Philippines': {'weight': 191.82699585},
#    'Poland': {'weight': 3968.6030273},
#    'Portugal': {'weight': 751.90002441},
#    'Romania': {'weight': 2509.657959},
#    'Russian Federation': {'weight': 1129.3649902},
#    'Senegal': {'weight': 1.3129999638},
#    'Serbia': {'weight': 1088.8790283},
#    'Singapore': {'weight': 373.55599976},
#    'Slovakia': {'weight': 70.928001404},
#    'Viet Nam': {'weight': 96434.6875},
#    'Slovenia': {'weight': 76.745002747},
#    'South Africa': {'weight': 13.993000031},
#    'Spain': {'weight': 1.4179999828},
#    'South Sudan': {'weight': 0.7630000114},
#    'Sweden': {'weight': 23836.888672},
#    'Switzerland, Liechtenstein': {'weight': 13865.525391},
#    'Tajikistan': {'weight': 573.34399414},
#    'Thailand': {'weight': 900.2789917},
#    'United Arab Emirates': {'weight': 0.3589999974},
#    'Tunisia': {'weight': 84.394996643},
#    'Türkiye': {'weight': 23685.339844},
#    'Ukraine': {'weight': 48.283000946},
#    'Egypt': {'weight': 14.157999992},
#    'Tanzania, United Republic of': {'weight': 8.8030004501},
#    'United States of America': {'weight': 75.267997742},
#    'United Kingdom': {'weight': 44812.910156}}),
#  ('American Samoa',
#   {'Australia': {'weight': 86.055999756},
#    'Cameroon': {'weight': 2.6210000515},
#    'Canada': {'weight': 5.7529997826},
#    'Costa Rica': {'weight': 28.458999634},
#    'Czechia': {'weight': 10.340999603},
#    'France': {'weight': 22.575000763},
#    'Germany': {'weight': 4.0450000763},
#    'Ghana': {'weight': 20.034999847},
#    'China, Hong Kong SAR': {'weight': 8373.1367188},
#    'Indonesia': {'weight': 71.98500061},
#    'Korea, Republic of': {'weight': 11.541000366},
#    'Malaysia': {'weight': 243.58999634},
#    'Netherlands': {'weight': 1070.6760254},
#    'New Zealand': {'weight': 26.584999084},
#    'Singapore': {'weight': 48.173999786},
#    'Slovakia': {'weight': 3.8910000324},
#    'Spain': {'weight': 1965.2259521},
#    'Tunisia': {'weight': 1362.756958},
#    'Tanzania, United Republic of': {'weight': 0.4370000064},
#    'Samoa': {'weight': 24.087999344},
#    'United Kingdom': {'weight': 9.8470001221}}),
#  ('Andorra',
#   {'Andorra': {'weight': 0.4620000124},
#    'Austria': {'weight': 18.694000244},
#    'Belgium': {'weight': 1.8109999895},
#    'Canada': {'weight': 0.7070000172},
#    'Sri Lanka': {'weight': 0.075000003},
#    'Chile': {'weight': 32.424999237},
#    'China': {'weight': 0.1509999931},
#    'China, Taiwan Province of': {'weight': 97.912002563},
#    'Cyprus': {'weight': 1.050999999},
#    'Czechia': {'weight': 5.4400000572},
#    'Denmark': {'weight': 2.9730000496},
#    'Finland': {'weight': 215.39399719},
#    'France': {'weight': 381.5880127},
#    'Germany': {'weight': 1.2350000143},
#    'China, Hong Kong SAR': {'weight': 283.30999756},
#    'Hungary': {'weight': 0.7570000291},
#    'Indonesia': {'weight': 0.9039999843},
#    'Iraq': {'weight': 2.6559998989},
#    'Ireland': {'weight': 0.0340000018},
#    'Israel': {'weight': 0.5070000291},
#    'Italy': {'weight': 34.409999847},
#    'Japan': {'weight': 20.353000641},
#    'Korea, Republic of': {'weight': 1379.4759521},
#    'Lithuania': {'weight': 1.3580000401},
#    'Malaysia': {'weight': 4.4180002213},
#    'Mexico': {'weight': 14.180000305},
#    'Netherlands': {'weight': 115.44599915},
#    'New Zealand': {'weight': 0.3580000103},
#    'Peru': {'weight': 0.2649999857},
#    'Philippines': {'weight': 3.3329999447},
#    'Poland': {'weight': 1.4730000496},
#    'Portugal': {'weight': 1.0839999914},
#    'Romania': {'weight': 0.2150000036},
#    'Russian Federation': {'weight': 0.9589999914},
#    'Singapore': {'weight': 5.736000061},
#    'Slovakia': {'weight': 6.5710000992},
#    'Viet Nam': {'weight': 28.544000626},
#    'Slovenia': {'weight': 0.1319999993},
#    'Spain': {'weight': 1327.7130127},
#    'Switzerland, Liechtenstein': {'weight': 29.322000504},
#    'Thailand': {'weight': 0.2210000008},
#    'United Arab Emirates': {'weight': 0.9850000143},
#    'Türkiye': {'weight': 0.3849999905},
#    'Ukraine': {'weight': 0.4420000017},
#    'United States of America': {'weight': 48.193000793},
#    'United Kingdom': {'weight': 23.620000839}}),
#  ('Angola',
#   {'Argentina': {'weight': 0.0489999987},
#    'Australia': {'weight': 11.296999931},
#    'Austria': {'weight': 1.0080000162},
#    'Bahamas': {'weight': 1.0410000086},
#    'Bangladesh': {'weight': 0.1270000041},
#    'Barbados': {'weight': 0.0839999989},
#    'Belgium': {'weight': 65.974998474},
#    'Brazil': {'weight': 3.3770000935},
#    'British Virgin Islands': {'weight': 6.0069999695},
#    'Bulgaria': {'weight': 0.123999998},
#    'Belarus': {'weight': 0.1640000045},
#    'Cameroon': {'weight': 0.275000006},
#    'Canada': {'weight': 18.207000732},
#    'Cabo Verde': {'weight': 0.3400000036},
#    'China': {'weight': 4.8850002289},
#    'China, Taiwan Province of': {'weight': 774.13201904},
#    'Colombia': {'weight': 113.09100342},
#    'Congo': {'weight': 38.40599823},
#    'Congo, Dem. Rep. of the': {'weight': 159.3500061},
#    'Costa Rica': {'weight': 15.607000351},
#    'Croatia': {'weight': 0.1299999952},
#    'Cuba': {'weight': 4.4730000496},
#    'Cyprus': {'weight': 0.976000011},
#    'Czechia': {'weight': 294.10198975},
#    'Benin': {'weight': 0.8429999948},
#    'Denmark': {'weight': 274.13800049},
#    'Dominican Republic': {'weight': 0.9639999866},
#    'Ethiopia': {'weight': 186.66400146},
#    'Finland': {'weight': 486.64700317},
#    'France': {'weight': 40.85200119},
#    'Gabon': {'weight': 4.6119999886},
#    'Gambia': {'weight': 0.9980000257},
#    'Germany': {'weight': 2.1400001049},
#    'Ghana': {'weight': 4.4019999504},
#    'Gibraltar': {'weight': 0.3109999895},
#    'Greece': {'weight': 1.0930000544},
#    'Guatemala': {'weight': 0.0719999969},
#    'Guinea': {'weight': 0.6660000086},
#    'China, Hong Kong SAR': {'weight': 351.05801392},
#    'Hungary': {'weight': 8.0780000687},
#    'India': {'weight': 0.057},
#    'Ireland': {'weight': 0.4129999876},
#    'Israel': {'weight': 14.43200016},
#    'Italy': {'weight': 641.37799072},
#    "Côte d'Ivoire": {'weight': 1.0010000467},
#    'Japan': {'weight': 321.5539856},
#    'Kenya': {'weight': 0.0359999985},
#    'Korea, Republic of': {'weight': 27.347000122},
#    'Kuwait': {'weight': 5.3369998932},
#    "Lao People's Dem. Rep.": {'weight': 3.496999979},
#    'Lebanon': {'weight': 0.6499999762},
#    'Lesotho': {'weight': 0.1860000044},
#    'Latvia': {'weight': 3.1480000019},
#    'Lithuania': {'weight': 48.730998993},
#    'Luxembourg': {'weight': 0.126000002},
#    'Madagascar': {'weight': 7.5229997635},
#    'Malaysia': {'weight': 10.668000221},
#    'Malta': {'weight': 3.3910000324},
#    'Mauritania': {'weight': 2.1670000553},
#    'Mauritius': {'weight': 1.2869999409},
#    'Mexico': {'weight': 14.475000381},
#    'Morocco': {'weight': 1.4049999714},
#    'Mozambique': {'weight': 3.3919999599},
#    'Namibia': {'weight': 1.3129999638},
#    'Netherlands': {'weight': 621.33300781},
#    'New Zealand': {'weight': 5.6529998779},
#    'Nigeria': {'weight': 15.100000381},
#    'Norway': {'weight': 258.17098999},
#    'Panama': {'weight': 19.267000198},
#    'Papua New Guinea': {'weight': 1029.1679688},
#    'Peru': {'weight': 0.0040000002},
#    'Philippines': {'weight': 0.9900000095},
#    'Poland': {'weight': 5.0539999008},
#    'Portugal': {'weight': 332.09799194},
#    'Qatar': {'weight': 0.2150000036},
#    'Romania': {'weight': 0.7030000091},
#    'Russian Federation': {'weight': 0.7850000262},
#    'Sao Tome and Principe': {'weight': 62.488998413},
#    'Saudi Arabia': {'weight': 58.194000244},
#    'Senegal': {'weight': 2.2920000553},
#    'Serbia': {'weight': 14.43500042},
#    'Singapore': {'weight': 26.663000107},
#    'Slovakia': {'weight': 0.0989999995},
#    'Viet Nam': {'weight': 130.90100098},
#    'South Africa': {'weight': 40.618999481},
#    'Spain': {'weight': 14.336999893},
#    'Sweden': {'weight': 3465.9760742},
#    'Switzerland, Liechtenstein': {'weight': 5.0780000687},
#    'Thailand': {'weight': 138.01199341},
#    'Togo': {'weight': 1.9240000248},
#    'United Arab Emirates': {'weight': 1.2319999933},
#    'Tunisia': {'weight': 5.501999855},
#    'Türkiye': {'weight': 1.4040000439},
#    'Ukraine': {'weight': 0.9610000253},
#    'Egypt': {'weight': 6.9299998283},
#    'Tanzania, United Republic of': {'weight': 0.6290000081},
#    'United States of America': {'weight': 132.36000061},
#    'Venezuela (Bolivarian Rep. of)': {'weight': 0.0359999985},
#    'Zambia': {'weight': 0.0610000007},
#    'United Kingdom': {'weight': 392.75900269}}),
#  ('Antigua and Barbuda',
#   {'Afghanistan': {'weight': 0.1870000064},
#    'Austria': {'weight': 0.7670000196},
#    'Bahamas': {'weight': 2.0529999733},
#    'Barbados': {'weight': 0.3160000145},
#    'Brazil': {'weight': 2.2149999142},
#    'Belize': {'weight': 0.5820000172},
#    'British Virgin Islands': {'weight': 0.0049999999},
#    'Cameroon': {'weight': 3.4760000706},
#    'Canada': {'weight': 0.0060000001},
#    'Cayman Islands': {'weight': 6.4590001106},
#    'China': {'weight': 0.0560000017},
#    'China, Taiwan Province of': {'weight': 6.4439997673},
#    'Costa Rica': {'weight': 0.0839999989},
#    'Cuba': {'weight': 0.0340000018},
#    'Dominica': {'weight': 1.3020000458},
#    'Dominican Republic': {'weight': 0.0599999987},
#    'Estonia': {'weight': 6.8790001869},
#    'Finland': {'weight': 0.1049999967},
#    'France': {'weight': 0.063000001},
#    'Germany': {'weight': 23.583000183},
#    'Greece': {'weight': 0.4029999971},
#    'Grenada': {'weight': 0.726000011},
#    'Guyana': {'weight': 0.0060000001},
#    'China, Hong Kong SAR': {'weight': 0.3289999962},
#    'Hungary': {'weight': 0.0140000004},
#    'Indonesia': {'weight': 0.2790000141},
#    'Ireland': {'weight': 0.0070000002},
#    'Israel': {'weight': 3.0699999332},
#    'Italy': {'weight': 1.3600000143},
#    'Jamaica': {'weight': 0.1490000039},
#    'Japan': {'weight': 375.0920105},
#    "Korea, Dem. People's Rep. of": {'weight': 76.799003601},
#    'Korea, Republic of': {'weight': 27.826999664},
#    'Latvia': {'weight': 19.952999115},
#    'Malaysia': {'weight': 3.5250000954},
#    'Mexico': {'weight': 70.999000549},
#    'Montserrat': {'weight': 29.165000916},
#    'Morocco': {'weight': 1.1130000353},
#    'Netherlands': {'weight': 0.3930000067},
#    'Curaçao': {'weight': 0.1019999981},
#    'Panama': {'weight': 3.6089999676},
#    'Philippines': {'weight': 0.0070000002},
#    'Poland': {'weight': 7.6500000954},
#    'Romania': {'weight': 0.0430000015},
#    'Saint Kitts and Nevis': {'weight': 0.3759999871},
#    'Anguilla': {'weight': 0.8870000243},
#    'Saint Lucia': {'weight': 0.1270000041},
#    'Saint Vincent and the Grenadines': {'weight': 0.6460000277},
#    'Senegal': {'weight': 2.2880001068},
#    'Singapore': {'weight': 0.5099999905},
#    'Viet Nam': {'weight': 50.550998688},
#    'Spain': {'weight': 0.0219999999},
#    'Sweden': {'weight': 0.3019999862},
#    'Switzerland, Liechtenstein': {'weight': 0.8840000033},
#    'Thailand': {'weight': 3.3190000057},
#    'Trinidad and Tobago': {'weight': 0.7160000205},
#    'United States of America': {'weight': 1.0959999561},
#    'United Kingdom': {'weight': 0.3059999943}}),
#  ('Azerbaijan',
#   {'Australia': {'weight': 21.083000183},
#    'Austria': {'weight': 22.540000916},
#    'Belgium': {'weight': 13.302000046},
#    'Brazil': {'weight': 0.0469999984},
#    'Bulgaria': {'weight': 5.3249998093},
#    'Belarus': {'weight': 8.4670000076},
#    'Canada': {'weight': 1.7130000591},
#    'Chile': {'weight': 2.5620000362},
#    'China': {'weight': 3.6870000362},
#    'China, Taiwan Province of': {'weight': 1197.2409668},
#    'Croatia': {'weight': 4.5110001564},
#    'Czechia': {'weight': 84.239997864},
#    'Denmark': {'weight': 0.65200001},
#    'Estonia': {'weight': 105.62599945},
#    'Finland': {'weight': 0.2339999974},
#    'France': {'weight': 22.691999435},
#    'Georgia': {'weight': 90.291000366},
#    'Germany': {'weight': 10.737999916},
#    'Greece': {'weight': 1.7130000591},
#    'China, Hong Kong SAR': {'weight': 48.794998169},
#    'Hungary': {'weight': 639.89599609},
#    'India': {'weight': 1.0789999962},
#    'Indonesia': {'weight': 0.0489999987},
#    'Iran (Islamic Republic of)': {'weight': 1.3860000372},
#    'Iraq': {'weight': 0.0209999997},
#    'Ireland': {'weight': 0.0689999983},
#    'Israel': {'weight': 0.1400000006},
#    'Italy': {'weight': 295.96798706},
#    'Japan': {'weight': 745.10198975},
#    'Kazakhstan': {'weight': 0.1089999974},
#    'Korea, Republic of': {'weight': 18.186000824},
#    'Latvia': {'weight': 1.0010000467},
#    'Lithuania': {'weight': 202.73800659},
#    'Luxembourg': {'weight': 0.5419999957},
#    'Malaysia': {'weight': 2821.75},
#    'Malta': {'weight': 5.1149997711},
#    'Mexico': {'weight': 1903.2619629},
#    'Oman': {'weight': 0.0670000017},
#    'Netherlands': {'weight': 2231.6689453},
#    'New Zealand': {'weight': 18.933000565},
#    'Norway': {'weight': 13.715999603},
#    'Philippines': {'weight': 51.458999634},
#    'Poland': {'weight': 2184.5910645},
#    'Portugal': {'weight': 10.368000031},
#    'Romania': {'weight': 130.55299377},
#    'Russian Federation': {'weight': 23.823999405},
#    'Senegal': {'weight': 65.355003357},
#    'Singapore': {'weight': 0.0520000011},
#    'Slovakia': {'weight': 59.187000275},
#    'Viet Nam': {'weight': 16455.828125},
#    'Slovenia': {'weight': 653.83898926},
#    'South Africa': {'weight': 1.0889999866},
#    'Spain': {'weight': 0.9679999948},
#    'Sweden': {'weight': 8.8210000992},
#    'Switzerland, Liechtenstein': {'weight': 1.0770000219},
#    'Tajikistan': {'weight': 0.6579999924},
#    'Thailand': {'weight': 0.2230000049},
#    'Trinidad and Tobago': {'weight': 0.3179999888},
#    'United Arab Emirates': {'weight': 0.9710000157},
#    'Tunisia': {'weight': 0.1770000011},
#    'Türkiye': {'weight': 105.13500214},
#    'Turkmenistan': {'weight': 67.935997009},
#    'Ukraine': {'weight': 25.770999908},
#    'Egypt': {'weight': 3.1570000648},
#    'United States of America': {'weight': 5.4499998093},
#    'Uruguay': {'weight': 0.3819999993},
#    'United Kingdom': {'weight': 23.952999115}}),
#  ('Argentina',
#   {'Argentina': {'weight': 2.4330000877},
#    'Australia': {'weight': 0.6299999952},
#    'Austria': {'weight': 327.82000732},
#    'Bangladesh': {'weight': 0.0799999982},
#    'Barbados': {'weight': 0.9539999962},
#    'Belgium': {'weight': 166.01600647},
#    'Bolivia (Plurinational State of)': {'weight': 176.95399475},
#    'Brazil': {'weight': 1308.118042},
#    'Bulgaria': {'weight': 0.2840000093},
#    'Myanmar': {'weight': 1320.6040039},
#    'Belarus': {'weight': 7.8979997635},
#    'Cambodia': {'weight': 522.72601318},
#    'Canada': {'weight': 29.740999222},
#    'Cabo Verde': {'weight': 0.5939999819},
#    'Chile': {'weight': 1064.4759521},
#    'China': {'weight': 593.20800781},
#    'China, Taiwan Province of': {'weight': 31519.626953},
#    'Colombia': {'weight': 317.15499878},
#    'Costa Rica': {'weight': 22.395000458},
#    'Czechia': {'weight': 4379.6630859},
#    'Denmark': {'weight': 4.3049998283},
#    'Dominican Republic': {'weight': 79.192001343},
#    'Ecuador': {'weight': 69.901000977},
#    'El Salvador': {'weight': 29.739999771},
#    'Estonia': {'weight': 25142.34375},
#    'Finland': {'weight': 583.29901123},
#    'France': {'weight': 4.1160001755},
#    'Germany': {'weight': 31.287000656},
#    'Greece': {'weight': 3.1300001144},
#    'Guatemala': {'weight': 62.861000061},
#    'Honduras': {'weight': 38.789001465},
#    'China, Hong Kong SAR': {'weight': 1233.6169434},
#    'Hungary': {'weight': 7.0190000534},
#    'Iceland': {'weight': 4.8080000877},
#    'India': {'weight': 6.2680001259},
#    'Indonesia': {'weight': 32.073001862},
#    'Iraq': {'weight': 1.9989999533},
#    'Ireland': {'weight': 92.072998047},
#    'Israel': {'weight': 73.339996338},
#    'Italy': {'weight': 47.63999939},
#    'Japan': {'weight': 5.4099998474},
#    'Kazakhstan': {'weight': 4.1539998055},
#    'Korea, Republic of': {'weight': 214.94400024},
#    'Kuwait': {'weight': 2.4059998989},
#    "Lao People's Dem. Rep.": {'weight': 3.635999918},
#    'Latvia': {'weight': 2532.5161133},
#    'Lithuania': {'weight': 80.866996765},
#    'Malaysia': {'weight': 0.5},
#    'Malta': {'weight': 63.421001434},
#    'Mexico': {'weight': 621.99401855},
#    'Morocco': {'weight': 6.0},
#    'Oman': {'weight': 2.3280000687},
#    'Netherlands': {'weight': 79.345001221},
#    'New Zealand': {'weight': 168.1269989},
#    'Nicaragua': {'weight': 66.690002441},
#    'Norway': {'weight': 896.66998291},
#    'Panama': {'weight': 43.161998749},
#    'Paraguay': {'weight': 1344.5770264},
#    'Peru': {'weight': 484.39700317},
#    'Philippines': {'weight': 2223.5209961},
#    'Poland': {'weight': 21938.992188},
#    'Portugal': {'weight': 0.2579999864},
#    'Romania': {'weight': 4426.3901367},
#    'Russian Federation': {'weight': 304.71899414},
#    'Saudi Arabia': {'weight': 6.4390001297},
#    'Singapore': {'weight': 2.378000021},
#    'Slovakia': {'weight': 215.49099731},
#    'Viet Nam': {'weight': 0.8460000157},
#    'Slovenia': {'weight': 82.708000183},
#    'South Africa': {'weight': 22.372999191},
#    'Spain': {'weight': 7.7309999466},
#    'Sudan': {'weight': 2.2869999409},
#    'Sweden': {'weight': 0.8659999967},
#    'Switzerland, Liechtenstein': {'weight': 52.875},
#    'Syrian Arab Republic': {'weight': 9.6590003967},
#    'Thailand': {'weight': 85.45300293},
#    'Trinidad and Tobago': {'weight': 19.799999237},
#    'United Arab Emirates': {'weight': 2.1119999886},
#    'Tunisia': {'weight': 184.71400452},
#    'Türkiye': {'weight': 3.4630000591},
#    'Ukraine': {'weight': 2046.1650391},
#    'Egypt': {'weight': 1.8450000286},
#    'United States of America': {'weight': 2704.5820312},
#    'Uruguay': {'weight': 1476.2609863},
#    'Venezuela (Bolivarian Rep. of)': {'weight': 39.458000183},
#    'United Kingdom': {'weight': 69.482002258}}),
#  ('Australia',
#   {'Afghanistan': {'weight': 10729.413086},
#    'Albania': {'weight': 0.7720000148},
#    'American Samoa': {'weight': 26.829000473},
#    'Angola': {'weight': 4.3790001869},
#    'Azerbaijan': {'weight': 47.24200058},
#    'Argentina': {'weight': 220.28399658},
#    'Australia': {'weight': 19411.646484},
#    'Austria': {'weight': 738.32000732},
#    'Bahrain': {'weight': 4069.9589844},
#    'Bangladesh': {'weight': 634.00701904},
#    'Armenia': {'weight': 7.8660001755},
#    'Belgium': {'weight': 739.54199219},
#    'Bermuda': {'weight': 33.182998657},
#    'Bhutan': {'weight': 2.7960000038},
#    'Bolivia (Plurinational State of)': {'weight': 23.516000748},
#    'Bosnia and Herzegovina': {'weight': 3.0460000038},
#    'Botswana': {'weight': 23.813999176},
#    'Brazil': {'weight': 1552.2519531},
#    'Solomon Islands': {'weight': 516.12298584},
#    'Brunei Darussalam': {'weight': 95.661003113},
#    'Bulgaria': {'weight': 325.94100952},
#    'Myanmar': {'weight': 106.14099884},
#    'Burundi': {'weight': 8.7720003128},
#    'Belarus': {'weight': 24.618000031},
#    'Cambodia': {'weight': 52.925998688},
#    'Cameroon': {'weight': 26.767999649},
#    'Canada': {'weight': 9792.5546875},
#    'Cabo Verde': {'weight': 31.374000549},
#    'Cayman Islands': {'weight': 36.256000519},
#    'Central African Republic': {'weight': 290.14801025},
#    'Sri Lanka': {'weight': 276.90301514},
#    'Chad': {'weight': 67.643997192},
#    'Chile': {'weight': 3553.4470215},
#    'China': {'weight': 124783.00781},
#    'China, Taiwan Province of': {'weight': 3798.8730469},
#    'Christmas Island': {'weight': 606.89398193},
#    'Cocos (Keeling) Islands': {'weight': 266.7170105},
#    'Colombia': {'weight': 14.100000381},
#    'Congo': {'weight': 13.690999985},
#    'Congo, Dem. Rep. of the': {'weight': 12.262000084},
#    'Cook Islands': {'weight': 56.978000641},
#    'Costa Rica': {'weight': 25.666999817},
#    'Croatia': {'weight': 35.749000549},
#    'Cyprus': {'weight': 40.801998138},
#    'Czechia': {'weight': 361.85198975},
#    'Benin': {'weight': 0.2090000063},
#    'Denmark': {'weight': 1441.7729492},
#    'Dominican Republic': {'weight': 1.6749999523},
#    'Ecuador': {'weight': 0.6019999981},
#    'Equatorial Guinea': {'weight': 2.7850000858},
#    'Ethiopia': {'weight': 269.80899048},
#    'Estonia': {'weight': 762.52398682},
#    'Falkland Islands (Malvinas)': {'weight': 1.074000001},
#    'Fiji': {'weight': 3598.2700195},
#    'Finland': {'weight': 1141.6569824},
#    'France': {'weight': 7469.9990234},
#    'French Polynesia': {'weight': 173.45399475},
#    'Georgia': {'weight': 0.8539999723},
#    'Germany': {'weight': 18021.015625},
#    'Ghana': {'weight': 260.34298706},
#    'Gibraltar': {'weight': 7.4710001945},
#    'Kiribati': {'weight': 387.19400024},
#    'Greece': {'weight': 57.557998657},
#    'Guam': {'weight': 1146.9040527},
#    'Guatemala': {'weight': 56.27299881},
#    'Honduras': {'weight': 13.032999992},
#    'China, Hong Kong SAR': {'weight': 197509.07812},
#    'Hungary': {'weight': 897.92700195},
#    'Iceland': {'weight': 146.67999268},
#    'India': {'weight': 6573.6450195},
#    'Indonesia': {'weight': 3969.394043},
#    'Iran (Islamic Republic of)': {'weight': 234.85600281},
#    'Iraq': {'weight': 33.342998505},
#    'Ireland': {'weight': 1004.6019897},
#    'Israel': {'weight': 3572.2050781},
#    'Italy': {'weight': 3196.1149902},
#    "Côte d'Ivoire": {'weight': 130.56500244},
#    'Jamaica': {'weight': 4.6319999695},
#    'Japan': {'weight': 12525.776367},
#    'Kazakhstan': {'weight': 326.52700806},
#    'Jordan': {'weight': 46.216999054},
#    'Kenya': {'weight': 90.276000977},
#    'Korea, Republic of': {'weight': 8134.777832},
#    'Kuwait': {'weight': 344.03799438},
#    'Kyrgyzstan': {'weight': 157.1519928},
#    "Lao People's Dem. Rep.": {'weight': 150.19799805},
#    'Lebanon': {'weight': 157.33099365},
#    'Latvia': {'weight': 87.539001465},
#    'Liberia': {'weight': 11.241999626},
#    'Lithuania': {'weight': 263.31100464},
#    'Luxembourg': {'weight': 5.0050001144},
#    'China, Macao SAR': {'weight': 736.00402832},
#    'Madagascar': {'weight': 3.6159999371},
#    'Malawi': {'weight': 3.3489999771},
#    'Malaysia': {'weight': 30623.984375},
#    'Maldives': {'weight': 281.0920105},
#    'Mali': {'weight': 422.87701416},
#    'Malta': {'weight': 40.886001587},
#    'Mauritania': {'weight': 105.92299652},
#    'Mauritius': {'weight': 19.962999344},
#    'Mexico': {'weight': 706.95697021},
#    'Mongolia': {'weight': 26.208000183},
#    'Montenegro': {'weight': 14.954000473},
#    'Morocco': {'weight': 36.75799942},
#    'Mozambique': {'weight': 1.9390000105},
#    'Oman': {'weight': 119.82700348},
#    'Namibia': {'weight': 1309.0789795},
#    'Nauru': {'weight': 62.569000244},
#    'Nepal': {'weight': 106.27600098},
#    'Netherlands': {'weight': 13787.073242},
#    'Curaçao': {'weight': 37.665000916},
#    'New Caledonia': {'weight': 1437.0},
#    'Vanuatu': {'weight': 520.17199707},
#    'New Zealand': {'weight': 147043.46875},
#    'Niger': {'weight': 9.0740003586},
#    'Nigeria': {'weight': 129.647995},
#    'Niue': {'weight': 74.982002258},
#    'Norfolk Island': {'weight': 48.319000244},
#    'Norway': {'weight': 1017.2860107},
#    'Northern Mariana Islands': {'weight': 3.7019999027},
#    'Micronesia (Federated States of)': {'weight': 60.047000885},
#    'Marshall Islands': {'weight': 1.5210000277},
#    'Palau': {'weight': 2.0840001106},
#    'Pakistan': {'weight': 808.14202881},
#    'Panama': {'weight': 99.039001465},
#    'Papua New Guinea': {'weight': 7737.0551758},
#    'Paraguay': {'weight': 6.5650000572},
#    'Peru': {'weight': 983.91699219},
#    'Philippines': {'weight': 2271.9008789},
#    'Poland': {'weight': 715.28997803},
#    'Portugal': {'weight': 184.79899597},
#    'Guinea-Bissau': {'weight': 2.128000021},
#    'Timor-Leste': {'weight': 321.70498657},
#    'Qatar': {'weight': 1246.243042},
#    'Romania': {'weight': 28514.072266},
#    'Russian Federation': {'weight': 440.3710022},
#    'Rwanda': {'weight': 8.5710000992},
#    'Saint Kitts and Nevis': {'weight': 5.8249998093},
#    'Saint Lucia': {'weight': 2.9839999676},
#    'Saint Vincent and the Grenadines': {'weight': 0.1720000058},
#    'Sao Tome and Principe': {'weight': 4.9219999313},
#    'Saudi Arabia': {'weight': 1271.4160156},
#    'Senegal': {'weight': 441.29000854},
#    'Serbia': {'weight': 34.833999634},
#    'Seychelles': {'weight': 8.6499996185},
#    'Sierra Leone': {'weight': 112.8730011},
#    'Singapore': {'weight': 48057.351562},
#    'Slovakia': {'weight': 53.01599884},
#    'Viet Nam': {'weight': 4610.0390625},
#    'Slovenia': {'weight': 5.3509998322},
#    'Somalia': {'weight': 18.493000031},
#    'South Africa': {'weight': 7766.2988281},
#    'Zimbabwe': {'weight': 3.1159999371},
#    'Spain': {'weight': 3952.3110352},
#    'South Sudan': {'weight': 12.937000275},
#    'Sudan': {'weight': 1.692999959},
#    'Eswatini': {'weight': 16.517999649},
#    'Sweden': {'weight': 3428.8459473},
#    'Switzerland, Liechtenstein': {'weight': 1380.243042},
#    'Syrian Arab Republic': {'weight': 2.0399999619},
#    'Tajikistan': {'weight': 2.1879999638},
#    'Thailand': {'weight': 11804.317383},
#    'Togo': {'weight': 6.75},
#    'Tonga': {'weight': 367.7789917},
#    'Trinidad and Tobago': {'weight': 8.6789999008},
#    'United Arab Emirates': {'weight': 51981.78125},
#    'Tunisia': {'weight': 51.317001343},
#    'Türkiye': {'weight': 570.01397705},
#    'Turkmenistan': {'weight': 142.80599976},
#    'Tuvalu': {'weight': 86.632003784},
#    'Uganda': {'weight': 489.01501465},
#    'Ukraine': {'weight': 126.93599701},
#    'North Macedonia': {'weight': 66.223999023},
#    'Egypt': {'weight': 313.03601074},
#    'Tanzania, United Republic of': {'weight': 343.38101196},
#    'United States of America': {'weight': 202663.70312},
#    'Burkina Faso': {'weight': 294.98901367},
#    'Uruguay': {'weight': 13.151000023},
#    'Uzbekistan': {'weight': 17.313999176},
#    'Venezuela (Bolivarian Rep. of)': {'weight': 47.069999695},
#    'Wallis and Futuna Islands': {'weight': 4.868999958},
#    'Samoa': {'weight': 380.64300537},
#    'Zambia': {'weight': 193.23500061},
#    'United Kingdom': {'weight': 47484.183594}}),
#  ('Austria',
#   {'Afghanistan': {'weight': 1.1150000095},
#    'Albania': {'weight': 9651.6660156},
#    'Algeria': {'weight': 14.93900013},
#    'Andorra': {'weight': 18.653999329},
#    'Angola': {'weight': 5.7109999657},
#    'Antigua and Barbuda': {'weight': 3.6840000153},
#    'Azerbaijan': {'weight': 411.15899658},
#    'Argentina': {'weight': 3785.7858887},
#    'Australia': {'weight': 5657.2709961},
#    'Bahamas': {'weight': 0.8299999833},
#    'Bahrain': {'weight': 176.67500305},
#    'Bangladesh': {'weight': 45.282001495},
#    'Armenia': {'weight': 39.52299881},
#    'Belgium': {'weight': 12606.954102},
#    'Bermuda': {'weight': 9.9610004425},
#    'Bhutan': {'weight': 0.7250000238},
#    'Bolivia (Plurinational State of)': {'weight': 80.748001099},
#    'Bosnia and Herzegovina': {'weight': 1716.6280518},
#    'Brazil': {'weight': 30051.697266},
#    'Belize': {'weight': 27.73800087},
#    'British Virgin Islands': {'weight': 4.5520000458},
#    'Bulgaria': {'weight': 19868.017578},
#    'Myanmar': {'weight': 0.5059999824},
#    'Burundi': {'weight': 0.0219999999},
#    'Belarus': {'weight': 1404.9510498},
#    'Cambodia': {'weight': 9.8439998627},
#    'Cameroon': {'weight': 55.050998688},
#    'Canada': {'weight': 4388.3808594},
#    'Cabo Verde': {'weight': 1.182000041},
#    'Cayman Islands': {'weight': 240.35899353},
#    'Sri Lanka': {'weight': 273.44000244},
#    'Chile': {'weight': 392.15600586},
#    'China': {'weight': 26057.074219},
#    'China, Taiwan Province of': {'weight': 9954.4296875},
#    'Colombia': {'weight': 707.440979},
#    'Congo, Dem. Rep. of the': {'weight': 0.2529999912},
#    'Costa Rica': {'weight': 838.55499268},
#    'Croatia': {'weight': 71222.15625},
#    'Cuba': {'weight': 23.145999908},
#    'Cyprus': {'weight': 9625.0019531},
#    'Czechia': {'weight': 45154.367188},
#    'Benin': {'weight': 5.0419998169},
#    'Denmark': {'weight': 15276.974609},
#    'Dominican Republic': {'weight': 15.034000397},
#    'Ecuador': {'weight': 1.6940000057},
#    'El Salvador': {'weight': 8.1669998169},
#    'Ethiopia': {'weight': 25.857999802},
#    'Eritrea': {'weight': 0.8569999933},
#    'Estonia': {'weight': 1951.0539551},
#    'Faroe Islands': {'weight': 640.58001709},
#    'Fiji': {'weight': 4.993999958},
#    'Finland': {'weight': 14198.400391},
#    'France': {'weight': 29743.853516},
#    'French Polynesia': {'weight': 0.9570000172},
#    'Gabon': {'weight': 2.7690000534},
#    'Georgia': {'weight': 93.338996887},
#    'Gambia': {'weight': 6.8200001717},
#    'State of Palestine': {'weight': 0.2520000041},
#    'Germany': {'weight': 440576.5},
#    'Ghana': {'weight': 46.423000336},
#    'Gibraltar': {'weight': 189.4940033},
#    'Greece': {'weight': 26301.181641},
#    'Greenland': {'weight': 11.498000145},
#    'Guatemala': {'weight': 0.625},
#    'Guinea': {'weight': 11.232000351},
#    'China, Hong Kong SAR': {'weight': 88684.851562},
#    'Hungary': {'weight': 66742.773438},
#    'Iceland': {'weight': 194.21499634},
#    'India': {'weight': 2682.3049316},
#    'Indonesia': {'weight': 555.88098145},
#    'Iran (Islamic Republic of)': {'weight': 1110.5100098},
#    'Iraq': {'weight': 116.23899841},
#    'Ireland': {'weight': 2322.9541016},
#    'Israel': {'weight': 5733.3481445},
#    'Italy': {'weight': 40692.464844},
#    "Côte d'Ivoire": {'weight': 1.1840000153},
#    'Jamaica': {'weight': 1.0529999733},
#    'Japan': {'weight': 15386.147461},
#    'Kazakhstan': {'weight': 44.442001343},
#    'Jordan': {'weight': 79.378997803},
#    'Kenya': {'weight': 311.19100952},
#    'Korea, Republic of': {'weight': 4806.1308594},
#    'Kuwait': {'weight': 222.32200623},
#    'Kyrgyzstan': {'weight': 17.207000732},
#    "Lao People's Dem. Rep.": {'weight': 1.550999999},
#    'Lebanon': {'weight': 60.426998138},
#    'Latvia': {'weight': 10529.329102},
#    'Liberia': {'weight': 5.9600000381},
#    'Libya': {'weight': 9.2449998856},
#    'Lithuania': {'weight': 2175.2548828},
#    'Luxembourg': {'weight': 11540.459961},
#    'China, Macao SAR': {'weight': 24.951000214},
#    'Malawi': {'weight': 0.5920000076},
#    'Malaysia': {'weight': 5130.4428711},
#    'Maldives': {'weight': 40.902000427},
#    'Mali': {'weight': 3.2430000305},
#    'Malta': {'weight': 7014.0991211},
#    'Mauritius': {'weight': 4.8619999886},
#    'Mexico': {'weight': 3094.6330566},
#    'Mongolia': {'weight': 14.0},
#    'Moldova, Republic of': {'weight': 368.42700195},
#    'Montenegro': {'weight': 1111.6199951},
#    'Morocco': {'weight': 279.6619873},
#    'Mozambique': {'weight': 2.2009999752},
#    'Oman': {'weight': 102.25700378},
#    'Namibia': {'weight': 340.12799072},
#    'Nepal': {'weight': 1.3489999771},
#    'Netherlands': {'weight': 49504.175781},
#    'Curaçao': {'weight': 17.325000763},
#    'Aruba': {'weight': 2.9769999981},
#    'New Caledonia': {'weight': 50.22700119},
#    'New Zealand': {'weight': 859.39001465},
#    'Nicaragua': {'weight': 7.0050001144},
#    'Niger': {'weight': 1.7719999552},
#    'Nigeria': {'weight': 64.167999268},
#    'Norway': {'weight': 8378.5654297},
#    'Marshall Islands': {'weight': 0.2099999934},
#    'Pakistan': {'weight': 56.953998566},
#    'Panama': {'weight': 87.725997925},
#    'Papua New Guinea': {'weight': 329.3210144},
#    'Paraguay': {'weight': 15.517000198},
#    'Peru': {'weight': 44.592998505},
#    'Philippines': {'weight': 706.8079834},
#    'Poland': {'weight': 139185.17188},
#    'Portugal': {'weight': 5204.8759766},
#    'Qatar': {'weight': 255.61999512},
#    'Romania': {'weight': 27017.492188},
#    'Russian Federation': {'weight': 3710.447998},
#    'Rwanda': {'weight': 2.2820000648},
#    'San Marino': {'weight': 0.2129999995},
#    'Saudi Arabia': {'weight': 1507.4279785},
#    'Senegal': {'weight': 8.045999527},
#    'Serbia': {'weight': 9626.2714844},
#    'Seychelles': {'weight': 8.4289999008},
#    'Sierra Leone': {'weight': 6.7960000038},
#    'Singapore': {'weight': 7553.1630859},
#    'Slovakia': {'weight': 132275.45312},
#    'Viet Nam': {'weight': 2377.0429688},
#    'Slovenia': {'weight': 78309.914062},
#    'Somalia': {'weight': 5.0460000038},
#    'South Africa': {'weight': 4081.0859375},
#    'Spain': {'weight': 24504.375},
#    'South Sudan': {'weight': 1.7029999495},
#    'Western Sahara': {'weight': 0.0089999996},
#    'Sweden': {'weight': 26532.117188},
#    'Switzerland, Liechtenstein': {'weight': 117497.70312},
#    'Syrian Arab Republic': {'weight': 0.201000005},
#    'Tajikistan': {'weight': 0.0060000001},
#    'Thailand': {'weight': 811.85900879},
#    'Togo': {'weight': 9.123000145},
#    'Tokelau': {'weight': 2.2509999275},
#    'United Arab Emirates': {'weight': 136340.3125},
#    'Tunisia': {'weight': 2881.3068848},
#    'Türkiye': {'weight': 5420.9311523},
#    'Turkmenistan': {'weight': 0.2960000038},
#    'Uganda': {'weight': 48.259998322},
#    'Ukraine': {'weight': 1125.9370117},
#    'North Macedonia': {'weight': 2997.1269531},
#    'Egypt': {'weight': 1393.1190186},
#    'Tanzania, United Republic of': {'weight': 1.7630000114},
#    'United States of America': {'weight': 581270.875},
#    'Burkina Faso': {'weight': 1.7940000296},
#    'Uruguay': {'weight': 18.042999268},
#    'Uzbekistan': {'weight': 40.275001526},
#    'Venezuela (Bolivarian Rep. of)': {'weight': 54.528999329},
#    'Samoa': {'weight': 1.8409999609},
#    'Yemen': {'weight': 2.1689999104},
#    'Zambia': {'weight': 69.181999207},
#    'United Kingdom': {'weight': 51747.589844}}),
#  ('Bahamas',
#   {'Angola': {'weight': 0.5230000019},
#    'Antigua and Barbuda': {'weight': 1.4040000439},
#    'Austria': {'weight': 0.1080000028},
#    'Barbados': {'weight': 0.2930000126},
#    'Belgium': {'weight': 5.9869999886},
#    'Bermuda': {'weight': 0.3840000033},
#    'Brazil': {'weight': 0.0189999994},
#    'Canada': {'weight': 0.0450000018},
#    'Cayman Islands': {'weight': 3.9979999065},
#    'Sri Lanka': {'weight': 0.0649999976},
#    'Chile': {'weight': 0.1620000005},
#    'China': {'weight': 1478.5279541},
#    'China, Taiwan Province of': {'weight': 0.878000021},
#    'Costa Rica': {'weight': 0.0309999995},
#    'Cyprus': {'weight': 3.2070000172},
#    'Czechia': {'weight': 0.3549999893},
#    'Denmark': {'weight': 0.2800000012},
#    'Dominican Republic': {'weight': 2.0959999561},
#    'Finland': {'weight': 0.0890000015},
#    'France': {'weight': 0.1889999956},
#    'Germany': {'weight': 14.288999557},
#    'Ghana': {'weight': 0.0469999984},
#    'Greece': {'weight': 40.958999634},
#    'Grenada': {'weight': 0.0560000017},
#    'Guatemala': {'weight': 0.9819999933},
#    'Honduras': {'weight': 0.0850000009},
#    'China, Hong Kong SAR': {'weight': 4.6830000877},
#    'India': {'weight': 5.6570000648},
#    'Israel': {'weight': 2.3310000896},
#    'Italy': {'weight': 1.118999958},
#    'Jamaica': {'weight': 0.3470000029},
#    'Japan': {'weight': 25.125},
#    'Korea, Republic of': {'weight': 2.4609999657},
#    'Latvia': {'weight': 0.0820000023},
#    'Malta': {'weight': 26.580999374},
#    'Mexico': {'weight': 651.0579834},
#    'Netherlands': {'weight': 0.1589999944},
#    'New Zealand': {'weight': 1.1809999943},
#    'Norway': {'weight': 13.013999939},
#    'Pakistan': {'weight': 0.5230000019},
#    'Panama': {'weight': 1595.3740234},
#    'Philippines': {'weight': 2.1300001144},
#    'Poland': {'weight': 0.0120000001},
#    'Romania': {'weight': 0.0250000004},
#    'Saint Kitts and Nevis': {'weight': 6.2459998131},
#    'Saint Lucia': {'weight': 0.063000001},
#    'Serbia': {'weight': 0.0500000007},
#    'Sierra Leone': {'weight': 0.1059999987},
#    'Singapore': {'weight': 0.0120000001},
#    'Slovenia': {'weight': 3.4849998951},
#    'South Africa': {'weight': 0.0199999996},
#    'Spain': {'weight': 0.0390000008},
#    'Sweden': {'weight': 1.7239999771},
#    'Switzerland, Liechtenstein': {'weight': 0.6529999971},
#    'Trinidad and Tobago': {'weight': 0.5619999766},
#    'Turks and Caicos Islands': {'weight': 0.2460000068},
#    'United States of America': {'weight': 139.86199951},
#    'United Kingdom': {'weight': 73.481002808}}),
#  ('Bahrain',
#   {'Australia': {'weight': 2607.072998},
#    'Austria': {'weight': 12.656999588},
#    'Bangladesh': {'weight': 388.89498901},
#    'Belgium': {'weight': 12.036000252},
#    'Brazil': {'weight': 0.8870000243},
#    'Bulgaria': {'weight': 1.0850000381},
#    'Myanmar': {'weight': 0.2549999952},
#    'Cameroon': {'weight': 0.9100000262},
#    'Canada': {'weight': 2.3220000267},
#    'Sri Lanka': {'weight': 4.1519999504},
#    'Chile': {'weight': 0.0140000004},
#    'China': {'weight': 95087.890625},
#    'China, Taiwan Province of': {'weight': 0.1049999967},
#    'Costa Rica': {'weight': 0.2280000001},
#    'Croatia': {'weight': 0.0960000008},
#    'Cyprus': {'weight': 0.800999999},
#    'Czechia': {'weight': 45.618999481},
#    'Denmark': {'weight': 10.989999771},
#    'Dominica': {'weight': 0.3000000119},
#    'Ecuador': {'weight': 5.5320000648},
#    'El Salvador': {'weight': 0.7480000257},
#    'Ethiopia': {'weight': 0.1360000074},
#    'Estonia': {'weight': 174.30499268},
#    'Finland': {'weight': 1.6139999628},
#    'France': {'weight': 182.06900024},
#    'French Polynesia': {'weight': 0.621999979},
#    'Germany': {'weight': 55.23400116},
#    'Ghana': {'weight': 10.489999771},
#    'Greece': {'weight': 4.8159999847},
#    'Holy See': {'weight': 233.53799438},
#    'China, Hong Kong SAR': {'weight': 3765.0039062},
#    'Hungary': {'weight': 0.5379999876},
#    'India': {'weight': 1.4700000286},
#    'Indonesia': {'weight': 0.8320000172},
#    'Iran (Islamic Republic of)': {'weight': 9.8109998703},
#    'Iraq': {'weight': 2.8650000095},
#    'Ireland': {'weight': 0.5550000072},
#    'Italy': {'weight': 18.743999481},
#    'Jamaica': {'weight': 0.8920000196},
#    'Japan': {'weight': 17.740999222},
#    'Jordan': {'weight': 18.006000519},
#    'Kenya': {'weight': 0.2529999912},
#    'Korea, Republic of': {'weight': 8.7089996338},
#    'Kuwait': {'weight': 322.92401123},
#    "Lao People's Dem. Rep.": {'weight': 1.5829999447},
#    'Lebanon': {'weight': 25.201999664},
#    'Latvia': {'weight': 20.819000244},
#    'Lithuania': {'weight': 0.2479999959},
#    'Luxembourg': {'weight': 0.6539999843},
#    'Malaysia': {'weight': 9.3409996033},
#    'Maldives': {'weight': 0.4539999962},
#    'Malta': {'weight': 0.1449999958},
#    'Mexico': {'weight': 812.27697754},
#    'Morocco': {'weight': 0.4869999886},
#    'Oman': {'weight': 12.270000458},
#    'Namibia': {'weight': 1.3259999752},
#    'Nauru': {'weight': 1.7790000439},
#    'Nepal': {'weight': 0.0340000018},
#    'Netherlands': {'weight': 1505.3740234},
#    'New Zealand': {'weight': 55.706001282},
#    'Norway': {'weight': 6.9450001717},
#    'Pakistan': {'weight': 2.5940001011},
#    'Philippines': {'weight': 11.491000175},
#    'Poland': {'weight': 0.4429999888},
#    'Portugal': {'weight': 1.1540000439},
#    'Qatar': {'weight': 62.462001801},
#    'Romania': {'weight': 13.696000099},
#    'Russian Federation': {'weight': 385.46499634},
#    'Saudi Arabia': {'weight': 110896.82031},
#    'Serbia': {'weight': 0.2129999995},
#    'Seychelles': {'weight': 2.0390000343},
#    'Sierra Leone': {'weight': 0.0170000009},
#    'Singapore': {'weight': 195.71600342},
#    'Slovakia': {'weight': 0.425999999},
#    'Viet Nam': {'weight': 1.9060000181},
#    'Slovenia': {'weight': 3.2769999504},
#    'South Africa': {'weight': 2.8929998875},
#    'Spain': {'weight': 0.3379999995},
#    'Sweden': {'weight': 220.50900269},
#    'Switzerland, Liechtenstein': {'weight': 5.8010001183},
#    'Thailand': {'weight': 1.1449999809},
#    'United Arab Emirates': {'weight': 7269.7490234},
#    'Tunisia': {'weight': 0.0250000004},
#    'Türkiye': {'weight': 6.9279999733},
#    'Uganda': {'weight': 0.4519999921},
#    'Ukraine': {'weight': 0.4539999962},
#    'North Macedonia': {'weight': 0.3919999897},
#    'Egypt': {'weight': 15.336999893},
#    'Tanzania, United Republic of': {'weight': 0.0649999976},
#    'United States of America': {'weight': 69.375},
#    'Venezuela (Bolivarian Rep. of)': {'weight': 32.556999207},
#    'United Kingdom': {'weight': 307.73599243}}),
#  ('Bangladesh',
#   {'Afghanistan': {'weight': 0.2109999955},
#    'Australia': {'weight': 3.1879999638},
#    'Austria': {'weight': 0.0460000001},
#    'Bahrain': {'weight': 353.6579895},
#    'Belgium': {'weight': 19.638999939},
#    'Bhutan': {'weight': 0.4079999924},
#    'Brazil': {'weight': 0.4740000069},
#    'Bulgaria': {'weight': 16.579999924},
#    'Belarus': {'weight': 49.006999969},
#    'Cambodia': {'weight': 0.3799999952},
#    'Cameroon': {'weight': 20.729999542},
#    'Canada': {'weight': 10.248999596},
#    'Sri Lanka': {'weight': 31.962999344},
#    'China': {'weight': 458.8039856},
#    'China, Taiwan Province of': {'weight': 24.402999878},
#    'Croatia': {'weight': 8.6420001984},
#    'Cyprus': {'weight': 0.6539999843},
#    'Czechia': {'weight': 0.3670000136},
#    'Benin': {'weight': 0.5329999924},
#    'Denmark': {'weight': 43.409999847},
#    'Dominican Republic': {'weight': 8.8859996796},
#    'Ethiopia': {'weight': 0.1049999967},
#    'Finland': {'weight': 3596.8378906},
#    'France': {'weight': 51.902999878},
#    'Germany': {'weight': 42.168998718},
#    'Ghana': {'weight': 1.9140000343},
#    'Greece': {'weight': 5.3319997787},
#    'Honduras': {'weight': 3.3740000725},
#    'China, Hong Kong SAR': {'weight': 3142.0629883},
#    'Hungary': {'weight': 57.14799881},
#    'India': {'weight': 2453.1159668},
#    'Indonesia': {'weight': 3.1579999924},
#    'Ireland': {'weight': 0.3580000103},
#    'Italy': {'weight': 17.399000168},
#    "Côte d'Ivoire": {'weight': 2158.0310059},
#    'Japan': {'weight': 23.687000275},
#    'Kenya': {'weight': 0.1019999981},
#    "Korea, Dem. People's Rep. of": {'weight': 85.369003296},
#    'Korea, Republic of': {'weight': 87.315002441},
#    'Kuwait': {'weight': 0.5600000024},
#    'Lebanon': {'weight': 0.25},
#    'Latvia': {'weight': 19.034999847},
#    'Liberia': {'weight': 0.0070000002},
#    'Lithuania': {'weight': 16.593999863},
#    'Luxembourg': {'weight': 0.0189999994},
#    'China, Macao SAR': {'weight': 1.1829999685},
#    'Malaysia': {'weight': 727.87402344},
#    'Maldives': {'weight': 0.1819999963},
#    'Mali': {'weight': 0.6389999986},
#    'Malta': {'weight': 0.0909999982},
#    'Mauritius': {'weight': 0.3400000036},
#    'Mexico': {'weight': 0.6299999952},
#    'Morocco': {'weight': 3.9619998932},
#    'Mozambique': {'weight': 0.0189999994},
#    'Oman': {'weight': 0.4149999917},
#    'Nepal': {'weight': 1010.6119995},
#    'Netherlands': {'weight': 144.26400757},
#    'New Zealand': {'weight': 0.7630000114},
#    'Nigeria': {'weight': 0.8759999871},
#    'Norway': {'weight': 2.4730000496},
#    'Pakistan': {'weight': 0.4250000119},
# ...
#    'Viet Nam': {'weight': 400.51098633},
#    'South Africa': {'weight': 2.9730000496},
#    'Spain': {'weight': 0.0890000015},
#    'Sweden': {'weight': 266.69198608},
#    'Thailand': {'weight': 78.708999634},
#    'Tonga': {'weight': 0.001},
#    'United States of America': {'weight': 2.9100000858},
#    'United Kingdom': {'weight': 36.653999329}}),
#  ('Yemen',
#   {'Andorra': {'weight': 0.2980000079},
#    'Australia': {'weight': 6.1859998703},
#    'Austria': {'weight': 0.0020000001},
#    'Belgium': {'weight': 0.0949999988},
#    'Cameroon': {'weight': 0.0350000001},
#    'Canada': {'weight': 0.878000021},
#    'China': {'weight': 2.9449999332},
#    'China, Taiwan Province of': {'weight': 0.003},
#    'Costa Rica': {'weight': 3.9249999523},
#    'Cuba': {'weight': 0.0529999994},
#    'Czechia': {'weight': 30.250999451},
#    'Denmark': {'weight': 1.121999979},
#    'Ethiopia': {'weight': 0.0060000001},
#    'Eritrea': {'weight': 3.7449998856},
#    'France': {'weight': 0.4620000124},
#    'Djibouti': {'weight': 60.444000244},
#    'Germany': {'weight': 3.5969998837},
#    'Greece': {'weight': 0.5009999871},
#    'China, Hong Kong SAR': {'weight': 17.420000076},
#    'Hungary': {'weight': 0.9620000124},
#    'India': {'weight': 0.0099999998},
#    'Indonesia': {'weight': 22.784000397},
#    'Iran (Islamic Republic of)': {'weight': 2.0880000591},
#    'Ireland': {'weight': 0.0020000001},
#    'Italy': {'weight': 83.406997681},
#    'Japan': {'weight': 4.5349998474},
#    'Jordan': {'weight': 0.3160000145},
#    'Kenya': {'weight': 0.0970000029},
#    'Korea, Republic of': {'weight': 9.6770000458},
#    'Kuwait': {'weight': 3.0150001049},
#    'Lebanon': {'weight': 13.434000015},
#    'Latvia': {'weight': 0.7369999886},
#    'Lithuania': {'weight': 1.057000041},
#    'Malaysia': {'weight': 45.48500061},
#    'Mexico': {'weight': 0.0250000004},
#    'Morocco': {'weight': 0.0060000001},
#    'Oman': {'weight': 1.6749999523},
#    'Netherlands': {'weight': 3.7599999905},
#    'Aruba': {'weight': 0.1920000017},
#    'Norway': {'weight': 0.2849999964},
#    'Pakistan': {'weight': 24.665000916},
#    'Philippines': {'weight': 0.5889999866},
#    'Poland': {'weight': 0.0},
#    'Portugal': {'weight': 0.1490000039},
#    'Qatar': {'weight': 0.2280000001},
#    'Romania': {'weight': 0.5329999924},
#    'Saint Kitts and Nevis': {'weight': 0.0},
#    'Saudi Arabia': {'weight': 0.0140000004},
#    'Singapore': {'weight': 0.0160000008},
#    'Slovakia': {'weight': 0.4009999931},
#    'Viet Nam': {'weight': 10.663000107},
#    'South Africa': {'weight': 0.0839999989},
#    'Zimbabwe': {'weight': 0.0329999998},
#    'Spain': {'weight': 23.74600029},
#    'Sudan': {'weight': 0.0209999997},
#    'Sweden': {'weight': 0.003},
#    'Switzerland, Liechtenstein': {'weight': 0.0020000001},
#    'Syrian Arab Republic': {'weight': 0.1330000013},
#    'Thailand': {'weight': 9.7980003357},
#    'United Arab Emirates': {'weight': 6.9850001335},
#    'Türkiye': {'weight': 0.0729999989},
#    'Egypt': {'weight': 0.001},
#    'Tanzania, United Republic of': {'weight': 0.0070000002},
#    'United States of America': {'weight': 606.96398926},
#    'United Kingdom': {'weight': 0.126000002}}),
#  ('Zambia',
#   {'Albania': {'weight': 1.1069999933},
#    'Andorra': {'weight': 2.5820000172},
#    'Angola': {'weight': 32.464000702},
#    'Australia': {'weight': 200.01699829},
#    'Austria': {'weight': 51.25},
#    'Belgium': {'weight': 2.4070000648},
#    'Botswana': {'weight': 2.013999939},
#    'Bulgaria': {'weight': 0.773999989},
#    'Burundi': {'weight': 0.0070000002},
#    'Cambodia': {'weight': 0.4029999971},
#    'Canada': {'weight': 10.477000237},
#    'Sri Lanka': {'weight': 0.8090000153},
#    'China': {'weight': 4.0809998512},
#    'China, Taiwan Province of': {'weight': 143.01400757},
#    'Colombia': {'weight': 0.2910000086},
#    'Congo': {'weight': 23.427999496},
#    'Congo, Dem. Rep. of the': {'weight': 123.52799988},
#    'Croatia': {'weight': 18.065999985},
#    'Cyprus': {'weight': 14.815999985},
#    'Czechia': {'weight': 0.8590000272},
#    'Denmark': {'weight': 216.01499939},
#    'Ethiopia': {'weight': 6.4120001793},
#    'Finland': {'weight': 99.786003113},
#    'France': {'weight': 16.301000595},
#    'Germany': {'weight': 3.1300001144},
#    'Ghana': {'weight': 13.456999779},
#    'Greece': {'weight': 482.48300171},
#    'China, Hong Kong SAR': {'weight': 160.05099487},
#    'India': {'weight': 773.06402588},
#    'Indonesia': {'weight': 166.48300171},
#    'Ireland': {'weight': 111.37200165},
#    'Israel': {'weight': 5.859000206},
#    'Italy': {'weight': 0.1889999956},
#    'Japan': {'weight': 846.59002686},
#    'Kenya': {'weight': 2.4409999847},
#    "Korea, Dem. People's Rep. of": {'weight': 5017.019043},
#    'Korea, Republic of': {'weight': 1293.2130127},
#    'Kuwait': {'weight': 2.1860001087},
#    'Lebanon': {'weight': 11.798000336},
#    'Lesotho': {'weight': 0.0460000001},
#    'Latvia': {'weight': 3.7119998932},
#    'Lithuania': {'weight': 158.45300293},
#    'Madagascar': {'weight': 0.0179999992},
#    'Malawi': {'weight': 492.90499878},
#    'Malaysia': {'weight': 23.330999374},
#    'Mauritania': {'weight': 2.2490000725},
#    'Mauritius': {'weight': 0.1669999957},
#    'Mexico': {'weight': 5.1500000954},
#    'Morocco': {'weight': 24.148000717},
#    'Mozambique': {'weight': 16.614999771},
#    'Namibia': {'weight': 1.5219999552},
#    'Netherlands': {'weight': 407.51400757},
#    'New Zealand': {'weight': 12.630000114},
#    'Nigeria': {'weight': 675.32501221},
#    'Norway': {'weight': 134.44999695},
#    'Panama': {'weight': 14.718999863},
#    'Philippines': {'weight': 2.6019999981},
#    'Poland': {'weight': 6.2239999771},
#    'Portugal': {'weight': 0.1490000039},
#    'Rwanda': {'weight': 0.398999989},
#    'Saudi Arabia': {'weight': 0.4629999995},
#    'Serbia': {'weight': 0.4280000031},
#    'Sierra Leone': {'weight': 2.8840000629},
#    'Singapore': {'weight': 715.83898926},
#    'Viet Nam': {'weight': 25591.775391},
#    'South Africa': {'weight': 1675.7290039},
#    'Zimbabwe': {'weight': 195.22399902},
#    'Spain': {'weight': 14.168000221},
#    'Eswatini': {'weight': 0.4850000143},
#    'Sweden': {'weight': 2.9370000362},
#    'Switzerland, Liechtenstein': {'weight': 0.1379999965},
#    'Thailand': {'weight': 0.0340000018},
#    'United Arab Emirates': {'weight': 117966.41406},
#    'Türkiye': {'weight': 3.0889999866},
#    'Uganda': {'weight': 37.071998596},
#    'Ukraine': {'weight': 0.4269999862},
#    'Egypt': {'weight': 9.6590003967},
#    'Tanzania, United Republic of': {'weight': 7.3460001945},
#    'United States of America': {'weight': 7.8070001602},
#    'Burkina Faso': {'weight': 11.699000359},
#    'United Kingdom': {'weight': 13.472000122}}),
#  ('United Kingdom',
#   {'Afghanistan': {'weight': 2608.1789551},
#    'Albania': {'weight': 820.92602539},
#    'Algeria': {'weight': 6974.7587891},
#    'American Samoa': {'weight': 30.827999115},
#    'Andorra': {'weight': 202.86399841},
#    'Angola': {'weight': 3429.1330566},
#    'Antigua and Barbuda': {'weight': 50.814998627},
#    'Azerbaijan': {'weight': 7707.8588867},
#    'Argentina': {'weight': 1387.0360107},
#    'Australia': {'weight': 67503.867188},
#    'Austria': {'weight': 43141.820312},
#    'Bahamas': {'weight': 89.926002502},
#    'Bahrain': {'weight': 4365.2021484},
#    'Bangladesh': {'weight': 1519.6369629},
#    'Armenia': {'weight': 379.31500244},
#    'Barbados': {'weight': 180.22200012},
#    'Belgium': {'weight': 113039.95312},
#    'Bermuda': {'weight': 214.79400635},
#    'Bolivia (Plurinational State of)': {'weight': 56.715999603},
#    'Bosnia and Herzegovina': {'weight': 364.00201416},
#    'Botswana': {'weight': 5513.546875},
#    'Brazil': {'weight': 18754.363281},
#    'Belize': {'weight': 4.7259998322},
#    'Solomon Islands': {'weight': 7.4800000191},
#    'British Virgin Islands': {'weight': 38.078998566},
#    'Brunei Darussalam': {'weight': 313.21600342},
#    'Bulgaria': {'weight': 20986.308594},
#    'Myanmar': {'weight': 250.72900391},
#    'Burundi': {'weight': 84.763000488},
#    'Belarus': {'weight': 357.45800781},
#    'Cambodia': {'weight': 199.89700317},
#    'Cameroon': {'weight': 2225.9309082},
#    'Canada': {'weight': 83461.085938},
#    'Cabo Verde': {'weight': 108.33200073},
#    'Cayman Islands': {'weight': 122.72799683},
#    'Central African Republic': {'weight': 279.27801514},
#    'Sri Lanka': {'weight': 1078.1920166},
#    'Chad': {'weight': 475.89599609},
#    'Chile': {'weight': 4941.4492188},
#    'China': {'weight': 376682.25},
#    'China, Taiwan Province of': {'weight': 34375.574219},
#    'Colombia': {'weight': 1357.3079834},
#    'Comoros': {'weight': 18.937999725},
#    'Congo': {'weight': 1228.605957},
#    'Congo, Dem. Rep. of the': {'weight': 375.39199829},
#    'Costa Rica': {'weight': 243.51699829},
#    'Croatia': {'weight': 9678.8466797},
#    'Cuba': {'weight': 254.43400574},
#    'Cyprus': {'weight': 8663.4248047},
#    'Czechia': {'weight': 67906.757812},
#    'Benin': {'weight': 301.29400635},
#    'Denmark': {'weight': 143100.70312},
#    'Dominica': {'weight': 4.7300000191},
#    'Dominican Republic': {'weight': 401.43399048},
#    'Ecuador': {'weight': 189.28700256},
#    'El Salvador': {'weight': 596.82501221},
#    'Equatorial Guinea': {'weight': 785.55999756},
#    'Ethiopia': {'weight': 11158.865234},
#    'Eritrea': {'weight': 37.498001099},
#    'Estonia': {'weight': 10159.744141},
#    'Faroe Islands': {'weight': 155.6309967},
#    'Falkland Islands (Malvinas)': {'weight': 1320.1070557},
#    'Fiji': {'weight': 160.13900757},
#    'Finland': {'weight': 63358.363281},
#    'France': {'weight': 634465.5},
#    'French Polynesia': {'weight': 492.13800049},
#    'Djibouti': {'weight': 511.56600952},
#    'Gabon': {'weight': 428.88299561},
#    'Georgia': {'weight': 1061.2779541},
#    'Gambia': {'weight': 213.60800171},
#    'Germany': {'weight': 758623.0},
#    'Ghana': {'weight': 2548.4489746},
#    'Gibraltar': {'weight': 6419.684082},
#    'Greece': {'weight': 62771.183594},
#    'Greenland': {'weight': 217.69999695},
#    'Grenada': {'weight': 28.586999893},
#    'Guam': {'weight': 171.41700745},
#    'Guatemala': {'weight': 119.93399811},
#    'Guinea': {'weight': 417.06900024},
#    'Guyana': {'weight': 183.6230011},
#    'Haiti': {'weight': 2.6740000248},
#    'Holy See': {'weight': 9.2440004349},
#    'Honduras': {'weight': 28.408000946},
#    'China, Hong Kong SAR': {'weight': 320184.03125},
#    'Hungary': {'weight': 58541.101562},
#    'Iceland': {'weight': 7566.4228516},
#    'India': {'weight': 55929.558594},
#    'Indonesia': {'weight': 8318.2050781},
#    'Iran (Islamic Republic of)': {'weight': 2218.8320312},
#    'Iraq': {'weight': 28875.472656},
#    'Ireland': {'weight': 491719.25},
#    'Israel': {'weight': 29414.746094},
#    'Italy': {'weight': 281985.5},
#    "Côte d'Ivoire": {'weight': 3734.8310547},
#    'Jamaica': {'weight': 241.55799866},
#    'Japan': {'weight': 45130.773438},
#    'Kazakhstan': {'weight': 3743.6269531},
#    'Jordan': {'weight': 4519.3891602},
#    'Kenya': {'weight': 7560.2402344},
#    "Korea, Dem. People's Rep. of": {'weight': 1.0809999704},
#    'Korea, Republic of': {'weight': 30303.355469},
#    'Kuwait': {'weight': 10078.538086},
#    'Kyrgyzstan': {'weight': 102.95800018},
#    "Lao People's Dem. Rep.": {'weight': 170.1289978},
#    'Lebanon': {'weight': 2978.1630859},
#    'Lesotho': {'weight': 30.197999954},
#    'Latvia': {'weight': 17975.193359},
#    'Liberia': {'weight': 162.96800232},
#    'Libya': {'weight': 1954.2060547},
#    'Lithuania': {'weight': 9718.3808594},
#    'Luxembourg': {'weight': 11984.300781},
#    'China, Macao SAR': {'weight': 7099.6860352},
#    'Madagascar': {'weight': 1042.5539551},
#    'Malawi': {'weight': 463.71099854},
#    'Malaysia': {'weight': 21842.138672},
#    'Maldives': {'weight': 251.58599854},
#    'Mali': {'weight': 2561.5769043},
#    'Malta': {'weight': 9593.5175781},
#    'Mauritania': {'weight': 804.12701416},
#    'Mauritius': {'weight': 8992.828125},
#    'Mexico': {'weight': 8392.2314453},
#    'Mongolia': {'weight': 276.49798584},
#    'Moldova, Republic of': {'weight': 389.07000732},
#    'Montenegro': {'weight': 111.51899719},
#    'Morocco': {'weight': 14677.428711},
#    'Mozambique': {'weight': 881.37097168},
#    'Oman': {'weight': 13932.522461},
#    'Namibia': {'weight': 896.69000244},
#    'Nauru': {'weight': 9.468000412},
#    'Nepal': {'weight': 1113.6700439},
#    'Netherlands': {'weight': 408660.0},
#    'Curaçao': {'weight': 24.454000473},
#    'Aruba': {'weight': 22.631000519},
#    'Sint Maarten (Dutch part)': {'weight': 32.951000214},
#    'Bonaire, Sint Eustatius and Saba': {'weight': 141.1230011},
#    'New Caledonia': {'weight': 340.91299438},
#    'Vanuatu': {'weight': 8.9600000381},
#    'New Zealand': {'weight': 9340.1660156},
#    'Nicaragua': {'weight': 18.124000549},
#    'Niger': {'weight': 352.64401245},
#    'Nigeria': {'weight': 18621.679688},
#    'Norway': {'weight': 62263.492188},
#    'Northern Mariana Islands': {'weight': 733.63201904},
#    'United States Minor Outlying Islands': {'weight': 154.54200745},
#    'Micronesia (Federated States of)': {'weight': 4.5570001602},
#    'Palau': {'weight': 13.241000175},
#    'Pakistan': {'weight': 4070.2670898},
#    'Panama': {'weight': 468.34899902},
#    'Papua New Guinea': {'weight': 1756.1989746},
#    'Paraguay': {'weight': 426.69500732},
#    'Peru': {'weight': 2711.1130371},
#    'Philippines': {'weight': 9632.2353516},
#    'Poland': {'weight': 121833.73438},
#    'Portugal': {'weight': 45677.378906},
#    'Guinea-Bissau': {'weight': 47.837001801},
#    'Timor-Leste': {'weight': 23.076999664},
#    'Qatar': {'weight': 16368.407227},
#    'Romania': {'weight': 24017.601562},
#    'Russian Federation': {'weight': 39732.675781},
#    'Rwanda': {'weight': 967.05499268},
#    'Saint Kitts and Nevis': {'weight': 6.5069999695},
#    'Anguilla': {'weight': 6.4869999886},
#    'Saint Lucia': {'weight': 14.496999741},
#    'Saint Pierre and Miquelon': {'weight': 5.1350002289},
#    'Saint Vincent and the Grenadines': {'weight': 56.207000732},
#    'San Marino': {'weight': 5.2039999962},
#    'Sao Tome and Principe': {'weight': 10.805999756},
#    'Saudi Arabia': {'weight': 126931.61719},
#    'Senegal': {'weight': 3380.3540039},
#    'Serbia': {'weight': 2885.3510742},
#    'Seychelles': {'weight': 634.14501953},
#    'Sierra Leone': {'weight': 376.37200928},
#    'Singapore': {'weight': 80591.484375},
#    'Slovakia': {'weight': 42310.1875},
#    'Viet Nam': {'weight': 22122.71875},
#    'Slovenia': {'weight': 6240.8740234},
#    'Somalia': {'weight': 225.83900452},
#    'South Africa': {'weight': 61738.027344},
#    'Zimbabwe': {'weight': 1438.8470459},
#    'Spain': {'weight': 232444.21875},
#    'South Sudan': {'weight': 36.182998657},
#    'Sudan': {'weight': 636.97900391},
#    'Suriname': {'weight': 79.977996826},
#    'Eswatini': {'weight': 19.162000656},
#    'Sweden': {'weight': 166444.45312},
#    'Switzerland, Liechtenstein': {'weight': 91272.960938},
#    'Syrian Arab Republic': {'weight': 1.9839999676},
#    'Tajikistan': {'weight': 27.048000336},
#    'Thailand': {'weight': 14862.400391},
#    'Togo': {'weight': 441.92300415},
#    'Trinidad and Tobago': {'weight': 1231.3260498},
#    'United Arab Emirates': {'weight': 628080.5},
#    'Tunisia': {'weight': 2132.9890137},
#    'Türkiye': {'weight': 48652.703125},
#    'Turkmenistan': {'weight': 2277.4399414},
#    'Turks and Caicos Islands': {'weight': 18.388999939},
#    'Uganda': {'weight': 1672.9620361},
#    'Ukraine': {'weight': 4135.3378906},
#    'North Macedonia': {'weight': 513.64898682},
#    'Egypt': {'weight': 17087.501953},
#    'Tanzania, United Republic of': {'weight': 2440.3710938},
#    'United States of America': {'weight': 730987.5625},
#    'Burkina Faso': {'weight': 112.38899994},
#    'Uruguay': {'weight': 2268.4279785},
#    'Uzbekistan': {'weight': 2764.0681152},
#    'Venezuela (Bolivarian Rep. of)': {'weight': 166.81100464},
#    'Samoa': {'weight': 7.4800000191},
#    'Yemen': {'weight': 318.96499634},
#    'Zambia': {'weight': 1696.5169678},
#    'United Kingdom': {'weight': 100237.49219}}),
#  ('Curaçao', {}),
#  ('Christmas Island', {}),
#  ('Cocos (Keeling) Islands', {}),
#  ('Norfolk Island', {}),
#  ('San Marino', {}),
#  ('Western Sahara', {}),
#  ('Holy See', {}),
#  ('French Southern Territories', {}),
#  ('Bouvet Island', {}),
#  ('United States Minor Outlying Islands', {}),
#  ('Pitcairn', {}),
#  ('British Indian Ocean Territory', {}),
#  ('Heard Island and McDonald Islands', {})]
